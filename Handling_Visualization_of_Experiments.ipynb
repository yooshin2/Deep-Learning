# %% [markdown]
# <a href="https://colab.research.google.com/github/yooshin2/Deep-Learning/blob/main/Handling_Visualization_of_Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir results

# %%
# !pip install -q torch==1.7.0 torchvision
import torch
print(torch.__version__)
# Out:
# 1.7.0+cu101

# %%
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np
import time
from copy import deepcopy # Add Deepcopy for args

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainset, valset = torch.utils.data.random_split(trainset, [40000, 10000])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
partition = {'train': trainset, 'val':valset, 'test':testset}
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, hid_dim, n_layer, act, dropout, use_bn, use_xavier):
        super(MLP, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.hid_dim = hid_dim
        self.n_layer = n_layer
        self.act = act
        self.dropout = dropout
        self.use_bn = use_bn
        self.use_xavier = use_xavier
        
        # ====== Create Linear Layers ====== #
        self.fc1 = nn.Linear(self.in_dim, self.hid_dim)
        
        self.linears = nn.ModuleList()
        self.bns = nn.ModuleList()
        for i in range(self.n_layer-1):
            self.linears.append(nn.Linear(self.hid_dim, self.hid_dim))
            if self.use_bn:
                self.bns.append(nn.BatchNorm1d(self.hid_dim))
                
        self.fc2 = nn.Linear(self.hid_dim, self.out_dim)
        
        # ====== Create Activation Function ====== #
        if self.act == 'relu':
            self.act = nn.ReLU()
        elif self.act == 'tanh':
            self.act == nn.Tanh()
        elif self.act == 'sigmoid':
            self.act = nn.Sigmoid()
        else:
            raise ValueError('no valid activation function selected!')
        
        # ====== Create Regularization Layer ======= #
        self.dropout = nn.Dropout(self.dropout)
        if self.use_xavier:
            self.xavier_init()
          
    def forward(self, x):
        x = self.act(self.fc1(x))
        for i in range(len(self.linears)):
            x = self.act(self.linears[i](x))
            x = self.bns[i](x)
            x = self.dropout(x)
        x = self.fc2(x)
        return x
    
    def xavier_init(self):
        for linear in self.linears:
            nn.init.xavier_normal_(linear.weight)
            linear.bias.data.fill_(0.01)
            
net = MLP(3072, 10, 100, 4, 'relu', 0.1, True, True) # Testing Model Construction

# %%
def train(net, partition, optimizer, criterion, args):
    trainloader = torch.utils.data.DataLoader(partition['train'], 
                                              batch_size=args.train_batch_size, 
                                              shuffle=True, num_workers=2)
    net.train()

    correct = 0
    total = 0
    train_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        optimizer.zero_grad() # [21.01.05 오류 수정] 매 Epoch 마다 .zero_grad()가 실행되는 것을 매 iteration 마다 실행되도록 수정했습니다. 

        # get the inputs
        inputs, labels = data
        inputs = inputs.view(-1, 3072)
        inputs = inputs.cuda()
        labels = labels.cuda()
        outputs = net(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = train_loss / len(trainloader)
    train_acc = 100 * correct / total
    return net, train_loss, train_acc

# %%
def validate(net, partition, criterion, args):
    valloader = torch.utils.data.DataLoader(partition['val'], 
                                            batch_size=args.test_batch_size, 
                                            shuffle=False, num_workers=2)
    net.eval()

    correct = 0
    total = 0
    val_loss = 0 
    with torch.no_grad():
        for data in valloader:
            images, labels = data
            images = images.view(-1, 3072)
            images = images.cuda()
            labels = labels.cuda()
            outputs = net(images)

            loss = criterion(outputs, labels)
            
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        val_loss = val_loss / len(valloader)
        val_acc = 100 * correct / total
    return val_loss, val_acc

# %%
def test(net, partition, args):
    testloader = torch.utils.data.DataLoader(partition['test'], 
                                             batch_size=args.test_batch_size, 
                                             shuffle=False, num_workers=2)
    net.eval()
    
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.view(-1, 3072)
            images = images.cuda()
            labels = labels.cuda()

            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        test_acc = 100 * correct / total
    return test_acc

# %%
def experiment(partition, args):
  
    net = MLP(args.in_dim, args.out_dim, args.hid_dim, args.n_layer, args.act, args.dropout, args.use_bn, args.use_xavier)
    net.cuda()

    criterion = nn.CrossEntropyLoss()
    if args.optim == 'SGD':
        optimizer = optim.RMSprop(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')
    
    # ===== List for epoch-wise data ====== #
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []
    # ===================================== #
        
    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        net, train_loss, train_acc = train(net, partition, optimizer, criterion, args)
        val_loss, val_acc = validate(net, partition, criterion, args)
        te = time.time()
        
        # ====== Add Epoch Data ====== #
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        # ============================ #
        
        print('Epoch {}, Acc(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.2f}/{:2.2f}. Took {:2.2f} sec'.format(epoch, train_acc, val_acc, train_loss, val_loss, te-ts))
        
    test_acc = test(net, partition, args)    
    
    # ======= Add Result to Dictionary ======= #
    result = {}
    result['train_losses'] = train_losses
    result['val_losses'] = val_losses
    result['train_accs'] = train_accs
    result['val_accs'] = val_accs
    result['train_acc'] = train_acc
    result['val_acc'] = val_acc
    result['test_acc'] = test_acc
    return vars(args), result
    # ===================================== #

# %%
import hashlib
import json
from os import listdir
from os.path import isfile, join
import pandas as pd

def save_exp_result(setting, result):
    exp_name = setting['exp_name']
    del setting['epoch']
    del setting['test_batch_size']

    hash_key = hashlib.sha1(str(setting).encode()).hexdigest()[:6]
    filename = './results/{}-{}.json'.format(exp_name, hash_key)
    result.update(setting)
    with open(filename, 'w') as f:
        json.dump(result, f)

    
def load_exp_result(exp_name):
    dir_path = './results'
    filenames = [f for f in listdir(dir_path) if isfile(join(dir_path, f)) if '.json' in f]
    list_result = []
    for filename in filenames:
        if exp_name in filename:
            with open(join(dir_path, filename), 'r') as infile:
                results = json.load(infile)
                list_result.append(results)
    df = pd.DataFrame(list_result) # .drop(columns=[])
    return df

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp1_n_layer_hid_dim"

# ====== Model Capacity ====== #
args.in_dim = 3072
args.out_dim = 10
args.hid_dim = 100
args.act = 'relu'

# ====== Regularization ======= #
args.dropout = 0.2
args.use_bn = True
args.l2 = 0.00001
args.use_xavier = True

# ====== Optimizer & Training ====== #
args.optim = 'RMSprop' #'RMSprop' #SGD, RMSprop, ADAM...
args.lr = 0.0015
args.epoch = 10

args.train_batch_size = 256
args.test_batch_size = 1024

# ====== Experiment Variable ====== #
name_var1 = 'n_layer'
name_var2 = 'hid_dim'
list_var1 = [1, 2, 3]
list_var2 = [500, 300]


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=1, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.96/37.75, Loss(train/val) 2.48/1.85. Took 9.10 sec
# Epoch 1, Acc(train/val): 46.20/40.07, Loss(train/val) 1.57/1.75. Took 9.17 sec
# Epoch 2, Acc(train/val): 48.86/39.87, Loss(train/val) 1.49/1.97. Took 9.02 sec
# Epoch 3, Acc(train/val): 51.54/44.48, Loss(train/val) 1.42/1.71. Took 9.00 sec
# Epoch 4, Acc(train/val): 52.46/42.39, Loss(train/val) 1.39/1.87. Took 8.73 sec
# Epoch 5, Acc(train/val): 54.91/41.37, Loss(train/val) 1.32/1.89. Took 8.86 sec
# Epoch 6, Acc(train/val): 56.95/38.40, Loss(train/val) 1.27/2.07. Took 8.83 sec
# Epoch 7, Acc(train/val): 58.10/42.10, Loss(train/val) 1.24/1.86. Took 8.75 sec
# Epoch 8, Acc(train/val): 60.23/42.78, Loss(train/val) 1.17/2.11. Took 8.76 sec
# Epoch 9, Acc(train/val): 61.67/47.44, Loss(train/val) 1.15/1.78. Took 8.74 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=1, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 38.82/34.80, Loss(train/val) 2.15/1.97. Took 8.81 sec
# Epoch 1, Acc(train/val): 46.38/40.83, Loss(train/val) 1.55/1.84. Took 9.07 sec
# Epoch 2, Acc(train/val): 49.72/41.09, Loss(train/val) 1.46/1.70. Took 8.90 sec
# Epoch 3, Acc(train/val): 51.75/41.02, Loss(train/val) 1.40/1.83. Took 8.88 sec
# Epoch 4, Acc(train/val): 54.11/41.38, Loss(train/val) 1.33/1.86. Took 9.01 sec
# Epoch 5, Acc(train/val): 55.62/42.91, Loss(train/val) 1.29/1.75. Took 9.02 sec
# Epoch 6, Acc(train/val): 57.41/42.17, Loss(train/val) 1.24/1.89. Took 8.66 sec
# Epoch 7, Acc(train/val): 58.90/46.40, Loss(train/val) 1.20/1.66. Took 8.85 sec
# Epoch 8, Acc(train/val): 60.37/37.57, Loss(train/val) 1.16/2.98. Took 8.90 sec
# Epoch 9, Acc(train/val): 62.25/45.17, Loss(train/val) 1.12/1.80. Took 8.77 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=2, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 36.90/39.73, Loss(train/val) 1.79/1.73. Took 9.20 sec
# Epoch 1, Acc(train/val): 45.84/39.28, Loss(train/val) 1.52/1.76. Took 8.97 sec
# Epoch 2, Acc(train/val): 49.74/43.10, Loss(train/val) 1.42/1.62. Took 9.15 sec
# Epoch 3, Acc(train/val): 52.75/45.41, Loss(train/val) 1.33/1.57. Took 8.94 sec
# Epoch 4, Acc(train/val): 55.38/40.69, Loss(train/val) 1.26/1.92. Took 8.98 sec
# Epoch 5, Acc(train/val): 57.55/45.97, Loss(train/val) 1.20/1.67. Took 9.24 sec
# Epoch 6, Acc(train/val): 60.27/48.69, Loss(train/val) 1.13/1.54. Took 9.00 sec
# Epoch 7, Acc(train/val): 61.98/49.57, Loss(train/val) 1.07/1.50. Took 9.35 sec
# Epoch 8, Acc(train/val): 64.39/51.47, Loss(train/val) 1.01/1.49. Took 9.13 sec
# Epoch 9, Acc(train/val): 66.40/49.46, Loss(train/val) 0.96/1.63. Took 9.34 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=2, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.78/37.13, Loss(train/val) 1.75/1.86. Took 9.12 sec
# Epoch 1, Acc(train/val): 46.25/42.07, Loss(train/val) 1.52/1.70. Took 9.09 sec
# Epoch 2, Acc(train/val): 49.99/45.98, Loss(train/val) 1.41/1.54. Took 9.02 sec
# Epoch 3, Acc(train/val): 52.55/45.51, Loss(train/val) 1.34/1.55. Took 8.83 sec
# Epoch 4, Acc(train/val): 54.83/48.28, Loss(train/val) 1.27/1.50. Took 9.10 sec
# Epoch 5, Acc(train/val): 57.12/48.79, Loss(train/val) 1.22/1.48. Took 8.93 sec
# Epoch 6, Acc(train/val): 58.99/49.15, Loss(train/val) 1.16/1.51. Took 9.04 sec
# Epoch 7, Acc(train/val): 60.97/50.20, Loss(train/val) 1.10/1.51. Took 9.01 sec
# Epoch 8, Acc(train/val): 62.84/51.36, Loss(train/val) 1.05/1.47. Took 9.20 sec
# Epoch 9, Acc(train/val): 64.42/48.39, Loss(train/val) 1.00/1.62. Took 9.01 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 35.73/38.05, Loss(train/val) 1.83/1.75. Took 9.18 sec
# Epoch 1, Acc(train/val): 45.28/37.74, Loss(train/val) 1.53/1.95. Took 9.41 sec
# Epoch 2, Acc(train/val): 49.23/39.93, Loss(train/val) 1.41/1.72. Took 9.11 sec
# Epoch 3, Acc(train/val): 52.16/46.93, Loss(train/val) 1.34/1.50. Took 9.17 sec
# Epoch 4, Acc(train/val): 54.93/40.42, Loss(train/val) 1.27/1.90. Took 9.16 sec
# Epoch 5, Acc(train/val): 57.31/48.69, Loss(train/val) 1.20/1.57. Took 9.53 sec
# Epoch 6, Acc(train/val): 59.31/47.83, Loss(train/val) 1.13/1.53. Took 9.09 sec
# Epoch 7, Acc(train/val): 59.59/49.40, Loss(train/val) 1.12/1.49. Took 9.15 sec
# Epoch 8, Acc(train/val): 62.48/49.12, Loss(train/val) 1.04/1.50. Took 9.16 sec
# Epoch 9, Acc(train/val): 64.23/54.11, Loss(train/val) 0.99/1.39. Took 9.00 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 36.50/39.11, Loss(train/val) 1.78/1.70. Took 9.33 sec
# Epoch 1, Acc(train/val): 45.54/43.99, Loss(train/val) 1.52/1.56. Took 9.23 sec
# Epoch 2, Acc(train/val): 49.41/45.64, Loss(train/val) 1.41/1.53. Took 9.38 sec
# Epoch 3, Acc(train/val): 52.53/45.11, Loss(train/val) 1.33/1.62. Took 9.15 sec
# Epoch 4, Acc(train/val): 54.58/48.21, Loss(train/val) 1.27/1.46. Took 9.53 sec
# Epoch 5, Acc(train/val): 56.84/48.79, Loss(train/val) 1.20/1.59. Took 9.43 sec
# Epoch 6, Acc(train/val): 59.15/48.27, Loss(train/val) 1.15/1.49. Took 9.06 sec
# Epoch 7, Acc(train/val): 60.96/46.39, Loss(train/val) 1.09/1.76. Took 9.29 sec
# Epoch 8, Acc(train/val): 62.38/49.78, Loss(train/val) 1.06/1.44. Took 9.44 sec
# Epoch 9, Acc(train/val): 64.30/48.93, Loss(train/val) 1.00/1.52. Took 9.32 sec

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

df = load_exp_result('exp1')

fig, ax = plt.subplots(1, 3)
fig.set_size_inches(15, 6)
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

sns.barplot(x='n_layer', y='train_acc', hue='hid_dim', data=df, ax=ax[0])
sns.barplot(x='n_layer', y='val_acc', hue='hid_dim', data=df, ax=ax[1])
sns.barplot(x='n_layer', y='test_acc', hue='hid_dim', data=df, ax=ax[2])

# %%
var1 = 'n_layer'
var2 = 'hid_dim'

df = load_exp_result('exp1')
list_v1 = df[var1].unique()
list_v2 = df[var2].unique()
list_data = []

for value1 in list_v1:
    for value2 in list_v2:
        row = df.loc[df[var1]==value1]
        row = row.loc[df[var2]==value2]
        
        train_losses = list(row.train_losses)[0]
        val_losses = list(row.val_losses)[0]
        
        for epoch, train_loss in enumerate(train_losses):
            list_data.append({'type':'train', 'loss':train_loss, 'epoch':epoch, var1:value1, var2:value2})
        for epoch, val_loss in enumerate(val_losses):
            list_data.append({'type':'val', 'loss':val_loss, 'epoch':epoch, var1:value1, var2:value2})
        
df = pd.DataFrame(list_data)
g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
g = g.map(plt.plot, 'epoch', 'loss', marker='.')
g.add_legend()
g.fig.suptitle('Train loss vs Val loss')
plt.subplots_adjust(top=0.89)

# %%
var1 = 'n_layer'
var2 = 'hid_dim'

df = load_exp_result('exp1')
list_v1 = df[var1].unique()
list_v2 = df[var2].unique()
list_data = []

for value1 in list_v1:
    for value2 in list_v2:
        row = df.loc[df[var1]==value1]
        row = row.loc[df[var2]==value2]
        
        train_accs = list(row.train_accs)[0]
        val_accs = list(row.val_accs)[0]
        test_acc = list(row.test_acc)[0]
        
        for epoch, train_acc in enumerate(train_accs):
            list_data.append({'type':'train', 'Acc':train_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
        for epoch, val_acc in enumerate(val_accs):
            list_data.append({'type':'val', 'Acc':val_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
        
df = pd.DataFrame(list_data)
g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
g = g.map(plt.plot, 'epoch', 'Acc', marker='.')

def show_acc(x, y, metric, **kwargs):
    plt.scatter(x, y, alpha=0.3, s=1)
    metric = "Test Acc: {:1.3f}".format(list(metric.values)[0])
    plt.text(0.05, 0.95, metric,  horizontalalignment='left', verticalalignment='center', transform=plt.gca().transAxes, bbox=dict(facecolor='yellow', alpha=0.5, boxstyle="round,pad=0.1"))
g = g.map(show_acc, 'epoch', 'Acc', 'test_acc')

g.add_legend()
g.fig.suptitle('Train Accuracy vs Val Accuracy')



plt.subplots_adjust(top=0.89)

# %%
# !ls results
# !cat results/exp1_n_layer_hid_dim-41b634.json
# Out:
# exp1_n_layer_hid_dim-41b634.json  exp1_n_layer_hid_dim-bfc899.json
# exp1_n_layer_hid_dim-61a2d0.json  exp1_n_layer_hid_dim-cab8c1.json
# exp1_n_layer_hid_dim-7b70fe.json  exp1_n_layer_hid_dim-dece45.json
# {"train_losses": [1.7759518304448219, 1.5196018302516572, 1.4098696723865096, 1.330137009833269, 1.2705231138095734, 1.2046598104914283, 1.1458121887437858, 1.094902346088628, 1.056277826713149, 1.0004449930919963], "val_losses": [1.6961228728294373, 1.5601871490478516, 1.5287163972854614, 1.6175867319107056, 1.456441056728363, 1.594411563873291, 1.4930568933486938, 1.7622117757797242, 1.4395114183425903, 1.5193845629692078], "train_accs": [36.4975, 45.5425, 49.41, 52.535, 54.58, 56.8375, 59.145, 60.9625, 62.3775, 64.3], "val_accs": [39.11, 43.99, 45.64, 45.11, 48.21, 48.79, 48.27, 46.39, 49.78, 48.93], "train_acc": 64.3, "val_acc": 48.93, "test_acc": 48.65, "exp_name": "exp1_n_layer_hid_dim", "in_dim": 3072, "out_dim": 10, "hid_dim": 300, "act": "relu", "dropout": 0.2, "use_bn": true, "l2": 1e-05, "use_xavier": true, "optim": "RMSprop", "lr": 0.0015, "train_batch_size": 256, "n_layer": 3}

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp2_lr_dropout"

# ====== Model Capacity ====== #
args.n_layer = 3
args.in_dim = 3072
args.out_dim = 10
args.hid_dim = 500
args.act = 'relu'

# ====== Regularization ======= #
#args.dropout = 0.2
args.use_bn = True
args.l2 = 0.00001
args.use_xavier = True

# ====== Optimizer & Training ====== #
args.optim = 'RMSprop' #'RMSprop' #SGD, RMSprop, ADAM...
#args.lr = 0.0015
args.epoch = 10

args.train_batch_size = 256
args.test_batch_size = 1024

# ====== Experiment Variable ====== #
name_var1 = 'lr'
name_var2 = 'dropout'
list_var1 = [0.0001, 0.001, 0.01]
list_var2 = [0.1, 0.25, 0.4]


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# Namespace(act='relu', dropout=0.1, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 40.84/44.30, Loss(train/val) 1.67/1.57. Took 9.03 sec
# Epoch 1, Acc(train/val): 49.60/47.60, Loss(train/val) 1.43/1.48. Took 9.15 sec
# Epoch 2, Acc(train/val): 53.60/47.52, Loss(train/val) 1.32/1.49. Took 9.55 sec
# Epoch 3, Acc(train/val): 56.87/49.59, Loss(train/val) 1.24/1.45. Took 9.34 sec
# Epoch 4, Acc(train/val): 59.44/49.72, Loss(train/val) 1.16/1.47. Took 9.49 sec
# Epoch 5, Acc(train/val): 61.94/51.47, Loss(train/val) 1.09/1.38. Took 9.58 sec
# Epoch 6, Acc(train/val): 64.59/51.44, Loss(train/val) 1.02/1.41. Took 9.52 sec
# Epoch 7, Acc(train/val): 67.25/48.44, Loss(train/val) 0.96/1.49. Took 9.82 sec
# Epoch 8, Acc(train/val): 69.01/50.22, Loss(train/val) 0.90/1.48. Took 9.33 sec
# Epoch 9, Acc(train/val): 70.95/50.84, Loss(train/val) 0.84/1.48. Took 9.45 sec
# Namespace(act='relu', dropout=0.25, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 38.11/42.80, Loss(train/val) 1.75/1.61. Took 9.21 sec
# Epoch 1, Acc(train/val): 45.55/46.66, Loss(train/val) 1.53/1.51. Took 9.48 sec
# Epoch 2, Acc(train/val): 49.39/48.47, Loss(train/val) 1.43/1.46. Took 9.28 sec
# Epoch 3, Acc(train/val): 52.22/49.25, Loss(train/val) 1.35/1.43. Took 9.16 sec
# Epoch 4, Acc(train/val): 54.40/49.80, Loss(train/val) 1.29/1.43. Took 9.29 sec
# Epoch 5, Acc(train/val): 56.76/50.74, Loss(train/val) 1.23/1.39. Took 9.29 sec
# Epoch 6, Acc(train/val): 58.34/51.89, Loss(train/val) 1.18/1.37. Took 9.24 sec
# Epoch 7, Acc(train/val): 60.02/52.45, Loss(train/val) 1.13/1.37. Took 9.63 sec
# Epoch 8, Acc(train/val): 61.80/53.56, Loss(train/val) 1.08/1.36. Took 9.38 sec
# Epoch 9, Acc(train/val): 63.62/53.07, Loss(train/val) 1.03/1.36. Took 9.36 sec
# Namespace(act='relu', dropout=0.4, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 35.01/43.15, Loss(train/val) 1.83/1.61. Took 9.22 sec
# Epoch 1, Acc(train/val): 42.71/46.22, Loss(train/val) 1.62/1.52. Took 9.45 sec
# Epoch 2, Acc(train/val): 45.73/48.53, Loss(train/val) 1.53/1.47. Took 9.32 sec
# Epoch 3, Acc(train/val): 48.22/48.31, Loss(train/val) 1.46/1.47. Took 9.59 sec
# Epoch 4, Acc(train/val): 50.31/49.89, Loss(train/val) 1.41/1.42. Took 10.09 sec
# Epoch 5, Acc(train/val): 51.74/48.85, Loss(train/val) 1.35/1.44. Took 9.22 sec
# Epoch 6, Acc(train/val): 53.52/50.58, Loss(train/val) 1.31/1.39. Took 9.58 sec
# Epoch 7, Acc(train/val): 54.95/51.63, Loss(train/val) 1.27/1.36. Took 9.47 sec
# Epoch 8, Acc(train/val): 56.61/52.64, Loss(train/val) 1.22/1.34. Took 9.35 sec
# Epoch 9, Acc(train/val): 57.87/51.67, Loss(train/val) 1.19/1.36. Took 9.16 sec
# Namespace(act='relu', dropout=0.1, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.69/41.60, Loss(train/val) 1.76/1.72. Took 9.46 sec
# Epoch 1, Acc(train/val): 47.62/44.77, Loss(train/val) 1.47/1.54. Took 9.11 sec
# Epoch 2, Acc(train/val): 51.55/47.09, Loss(train/val) 1.35/1.50. Took 9.56 sec
# Epoch 3, Acc(train/val): 55.22/47.03, Loss(train/val) 1.25/1.52. Took 9.54 sec
# Epoch 4, Acc(train/val): 58.05/45.02, Loss(train/val) 1.17/1.62. Took 9.16 sec
# Epoch 5, Acc(train/val): 60.93/45.22, Loss(train/val) 1.09/1.64. Took 9.24 sec
# Epoch 6, Acc(train/val): 63.73/49.14, Loss(train/val) 1.01/1.56. Took 8.97 sec
# Epoch 7, Acc(train/val): 66.35/46.27, Loss(train/val) 0.94/1.76. Took 9.22 sec
# Epoch 8, Acc(train/val): 69.00/49.20, Loss(train/val) 0.86/1.61. Took 9.33 sec
# Epoch 9, Acc(train/val): 71.97/49.49, Loss(train/val) 0.79/1.79. Took 9.47 sec
# Namespace(act='relu', dropout=0.25, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 36.98/40.68, Loss(train/val) 1.79/1.67. Took 9.40 sec
# Epoch 1, Acc(train/val): 46.07/42.78, Loss(train/val) 1.51/1.61. Took 9.51 sec
# Epoch 2, Acc(train/val): 49.85/44.24, Loss(train/val) 1.39/1.55. Took 9.08 sec
# Epoch 3, Acc(train/val): 52.84/48.72, Loss(train/val) 1.31/1.45. Took 9.39 sec
# Epoch 4, Acc(train/val): 55.44/47.50, Loss(train/val) 1.24/1.49. Took 9.38 sec
# Epoch 5, Acc(train/val): 57.73/46.54, Loss(train/val) 1.18/1.58. Took 9.15 sec
# Epoch 6, Acc(train/val): 60.25/49.71, Loss(train/val) 1.11/1.48. Took 9.65 sec
# Epoch 7, Acc(train/val): 61.84/51.46, Loss(train/val) 1.06/1.47. Took 9.49 sec
# Epoch 8, Acc(train/val): 64.47/48.86, Loss(train/val) 1.00/1.55. Took 9.60 sec
# Epoch 9, Acc(train/val): 65.76/50.30, Loss(train/val) 0.95/1.55. Took 9.63 sec
# Namespace(act='relu', dropout=0.4, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 34.89/41.88, Loss(train/val) 1.83/1.63. Took 9.26 sec
# Epoch 1, Acc(train/val): 43.98/44.24, Loss(train/val) 1.56/1.54. Took 9.21 sec
# Epoch 2, Acc(train/val): 47.95/45.12, Loss(train/val) 1.45/1.60. Took 9.16 sec
# Epoch 3, Acc(train/val): 50.63/48.45, Loss(train/val) 1.37/1.44. Took 9.25 sec
# Epoch 4, Acc(train/val): 53.22/47.99, Loss(train/val) 1.31/1.46. Took 9.24 sec
# Epoch 5, Acc(train/val): 55.50/47.10, Loss(train/val) 1.25/1.52. Took 9.13 sec
# Epoch 6, Acc(train/val): 57.71/50.41, Loss(train/val) 1.20/1.43. Took 9.41 sec
# Epoch 7, Acc(train/val): 59.07/51.64, Loss(train/val) 1.14/1.42. Took 9.45 sec
# Epoch 8, Acc(train/val): 60.55/51.72, Loss(train/val) 1.10/1.39. Took 9.41 sec
# Epoch 9, Acc(train/val): 62.65/49.87, Loss(train/val) 1.05/1.47. Took 9.33 sec
# Namespace(act='relu', dropout=0.1, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.01, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 27.98/25.61, Loss(train/val) 2.75/2.13. Took 9.00 sec
# Epoch 1, Acc(train/val): 37.57/30.39, Loss(train/val) 1.74/3.00. Took 9.27 sec
# Epoch 2, Acc(train/val): 41.55/37.39, Loss(train/val) 1.62/1.83. Took 9.38 sec
# Epoch 3, Acc(train/val): 45.16/39.94, Loss(train/val) 1.53/2.29. Took 9.58 sec
# Epoch 4, Acc(train/val): 47.84/35.79, Loss(train/val) 1.45/5.00. Took 9.05 sec
# Epoch 5, Acc(train/val): 49.80/38.34, Loss(train/val) 1.40/2.24. Took 9.22 sec
# Epoch 6, Acc(train/val): 50.70/45.08, Loss(train/val) 1.37/1.56. Took 9.78 sec
# Epoch 7, Acc(train/val): 52.56/37.54, Loss(train/val) 1.33/1.78. Took 9.38 sec
# Epoch 8, Acc(train/val): 53.00/40.41, Loss(train/val) 1.31/1.83. Took 9.61 sec
# Epoch 9, Acc(train/val): 54.70/44.12, Loss(train/val) 1.27/1.68. Took 9.01 sec
# Namespace(act='relu', dropout=0.25, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.01, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 27.46/28.58, Loss(train/val) 2.75/2.26. Took 9.39 sec
# Epoch 1, Acc(train/val): 37.20/34.22, Loss(train/val) 1.74/2.30. Took 9.61 sec
# Epoch 2, Acc(train/val): 42.33/37.47, Loss(train/val) 1.60/4.88. Took 9.68 sec
# Epoch 3, Acc(train/val): 45.16/37.26, Loss(train/val) 1.53/1.86. Took 9.82 sec
# Epoch 4, Acc(train/val): 46.85/40.26, Loss(train/val) 1.48/2.05. Took 9.45 sec
# Epoch 5, Acc(train/val): 48.81/36.05, Loss(train/val) 1.44/3.13. Took 9.55 sec
# Epoch 6, Acc(train/val): 49.84/36.74, Loss(train/val) 1.40/2.20. Took 9.09 sec
# Epoch 7, Acc(train/val): 51.43/34.20, Loss(train/val) 1.36/1.86. Took 9.22 sec
# Epoch 8, Acc(train/val): 50.26/41.99, Loss(train/val) 1.39/1.74. Took 9.64 sec
# Epoch 9, Acc(train/val): 52.62/36.22, Loss(train/val) 1.33/1.94. Took 9.19 sec
# Namespace(act='relu', dropout=0.4, epoch=10, exp_name='exp2_lr_dropout', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.01, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 26.00/26.98, Loss(train/val) 2.71/5.28. Took 9.36 sec
# Epoch 1, Acc(train/val): 34.80/33.02, Loss(train/val) 1.81/12.12. Took 9.23 sec
# Epoch 2, Acc(train/val): 39.24/37.18, Loss(train/val) 1.68/1.74. Took 9.30 sec
# Epoch 3, Acc(train/val): 41.83/37.75, Loss(train/val) 1.61/3.87. Took 9.74 sec
# Epoch 4, Acc(train/val): 44.42/38.67, Loss(train/val) 1.55/2.65. Took 9.64 sec
# Epoch 5, Acc(train/val): 46.51/43.13, Loss(train/val) 1.50/1.66. Took 9.30 sec
# Epoch 6, Acc(train/val): 47.75/43.18, Loss(train/val) 1.46/1.61. Took 9.67 sec
# Epoch 7, Acc(train/val): 48.84/43.97, Loss(train/val) 1.43/1.57. Took 9.38 sec
# Epoch 8, Acc(train/val): 49.92/41.02, Loss(train/val) 1.40/1.80. Took 9.22 sec
# Epoch 9, Acc(train/val): 51.34/39.98, Loss(train/val) 1.37/1.87. Took 9.54 sec

# %%
var1 = 'lr'
var2 = 'dropout'

df = load_exp_result('exp2')
list_v1 = df[var1].unique()
list_v2 = df[var2].unique()
list_data = []

for value1 in list_v1:
    for value2 in list_v2:
        row = df.loc[df[var1]==value1]
        row = row.loc[df[var2]==value2]
        
        train_losses = list(row.train_losses)[0]
        val_losses = list(row.val_losses)[0]
        
        for epoch, train_loss in enumerate(train_losses):
            list_data.append({'type':'train', 'loss':train_loss, 'epoch':epoch, var1:value1, var2:value2})
        for epoch, val_loss in enumerate(val_losses):
            list_data.append({'type':'val', 'loss':val_loss, 'epoch':epoch, var1:value1, var2:value2})
        
df = pd.DataFrame(list_data)
g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
g = g.map(plt.plot, 'epoch', 'loss', marker='.')
g.add_legend()
g.fig.suptitle('Train loss vs Val loss')
plt.subplots_adjust(top=0.89)

# %%
var1 = 'lr'
var2 = 'dropout'

df = load_exp_result('exp2')
list_v1 = df[var1].unique()
list_v2 = df[var2].unique()
list_data = []

for value1 in list_v1:
    for value2 in list_v2:
        row = df.loc[df[var1]==value1]
        row = row.loc[df[var2]==value2]
        
        train_accs = list(row.train_accs)[0]
        val_accs = list(row.val_accs)[0]
        test_acc = list(row.test_acc)[0]
        
        for epoch, train_acc in enumerate(train_accs):
            list_data.append({'type':'train', 'Acc':train_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
        for epoch, val_acc in enumerate(val_accs):
            list_data.append({'type':'val', 'Acc':val_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
        
df = pd.DataFrame(list_data)
g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
g = g.map(plt.plot, 'epoch', 'Acc', marker='.')

def show_acc(x, y, metric, **kwargs):
    plt.scatter(x, y, alpha=0.3, s=1)
    metric = "Test Acc: {:1.3f}".format(list(metric.values)[0])
    plt.text(0.05, 0.95, metric,  horizontalalignment='left', verticalalignment='center', transform=plt.gca().transAxes, bbox=dict(facecolor='yellow', alpha=0.5, boxstyle="round,pad=0.1"))
g = g.map(show_acc, 'epoch', 'Acc', 'test_acc')

g.add_legend()
g.fig.suptitle('Train Accuracy vs Val Accuracy')



plt.subplots_adjust(top=0.89)
